# %%
import numpy as np
import pandas as pd

# %%
df_main = pd.read_csv('chassi.csv')



df_find = pd.read_csv('recno.csv')
# Out:
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_260\1327061279.py:1: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_main = pd.read_csv('chassi.csv')

# %%
df_main.dtypes
# Out:
# RECNO                     float64
# TName                      object
# Company                    object
# Div_LES                    object
# Terminal                   object
# Status                     object
# ChassisNo                  object
# CONTAINERNO                object
# LI_NO                     float64
# QTY_LE                    float64
# SVCCODE_LE                 object
# SVCDESCRIPTION_LE          object
# RATECODE_LE                object
# RATE_LE                   float64
# CHGAMT_LE                 float64
# chz_pickup_loc             object
# Shipper_Name               object
# ConsigneeID                object
# Consignee_Name             object
# BilltoID_LES               object
# Billto_Name_LES            object
# Preferred                  object
# WorkorderNo                object
# PBI_RefNo                  object
# BOL                        object
# SSL                        object
# PU_Date                    object
# PU_Time                   float64
# Original_SchedDelv         object
# SchedDelv                  object
# Original_scheddelvtime    float64
# Scheddelvtime             float64
# POD_Date                   object
# POD_Time                   object
# Ingatedate                 object
# ReturnTo                   object
# CHZ_returnTo               object
# CHZ_ingatedate             object
# RECEIVEDBY                 object
# YARDID                     object
# LASTFREEDAY                object
# FREEDAYS                  float64
# LAST_RETURN                object
# Linehaul_Amount           float64
# FSC_Amount                float64
# Line_Total                float64
# ChasFee_Total             float64
# EL_Bill_Total             float64
# DP_Total                  float64
# MP_Total                  float64
# Net_Total                 float64
# Rel_Date                   object
# Billed_Date_LES            object
# Rcvd_Date_LES              object
# CUST_REF                   object
# dtype: object

# %%
n = 0

for x, y in df_find['recno'].iteritems():
    new_df = df_main[df_main['RECNO'].isin([y])]
    break
    
for x, y in df_find['recno'].iteritems():
    check = df_main['RECNO'].isin([y])
    if check.any() == True:
        to_append = df_main[df_main['RECNO'].isin([y])]
        new_df = new_df.append(to_append)
        
        
    else:
        n+=1
        new_df = new_df.append(pd.Series(), ignore_index = True)
        new_df.fillna(value = n, inplace =True)


new_df.columns

real_df = new_df[['RECNO', 'ChassisNo']]

real_df.drop_duplicates(inplace=True)

real_df.head(10)
# Out:
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_260\21800494.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_260\21800494.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_260\21800494.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_260\21800494.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_260\21800494.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_260\21800494.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_260\21800494.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_260\21800494.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_260\21800494.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_260\21800494.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_260\21800494.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_260\21800494.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_260\21800494.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_260\21800494.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_260\21800494.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_df.drop_duplicates(inplace=True)
#            RECNO   ChassisNo
# 15091  1935914.0  NAPZ405746
# 18314  1937274.0  NEDZ403010
# 19189  1937912.0  APMZ411906
# 19058  1937703.0  TLXZ524881
# 15095  1935915.0  FVXZ174897
# 16573  1936432.0  APMZ423981
# 16494  1936413.0  KKLZ602142
# 17419  1936783.0  TLXZ412945
# 16394  1936371.0  DCLZ400191
# 17650  1936910.0  NEDZ402046

# %%
with pd.ExcelWriter('yst_out.xlsx') as writer:
    real_df.to_excel(writer, sheet_name='Sheet 1')
