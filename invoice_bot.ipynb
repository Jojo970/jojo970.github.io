# %%
import numpy as np
import pandas as pd

# %%
df_main = pd.read_csv('Book1.csv', encoding = 'unicode_escape')

df_find = pd.read_csv('Book2.csv')

# %%
#clean the data frame by dropping duplicates and sorting by value first

df_main.drop_duplicates(subset = ['Container No'], inplace = True)

df_main.dtypes
# Out:
# RECNO             int64
# Ter              object
# SSL              object
# ID               object
# Consignee        object
# Container No     object
# Chassis No       object
# Unnamed: 7       object
# Unnamed: 8       object
# Unnamed: 9       object
#  EL Bill        float64
# Unnamed: 11      object
# WO #             object
# BOL #            object
# Unnamed: 14      object
# Unnamed: 15      object
# dtype: object

# %%
# pull rows where container names are contained and append to empty dataframe
names = ['RECNO ', 'Ter ', 'SSL', 'ID ', 'Consignee', 'Container No', 'Chassis No', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', '  EL Bill', 'Unnamed: 11', 'WO #', 'BOL #', 'Unnamed: 14', 'Unnamed: 15']
values = [0, 'NA','NA', 'NA', 'NA', 'NA', 'NA','NA', 'NA', 'NA',0.0, 'NA', 'NA', 'NA','NA', 'NA']


s2 = pd.DataFrame(values)

n = 0

for x, y in df_find['container'].iteritems():
    new_df = df_main[df_main['Container No'].isin([y])]
    break
    
for x, y in df_find['container'].iteritems():
    check = df_main['Container No'].isin([y])
    if check.any() == True:
        to_append = df_main[df_main['Container No'].isin([y])]
        new_df = new_df.append(to_append)
        
    else:
        n+=1
        new_df = new_df.append(pd.Series(), ignore_index = True)
        new_df.fillna(value = n, inplace =True)
   
new_df['customer/consignee'] = new_df['ID '].astype(str) + "/" + new_df['Consignee'].astype(str)

new_df.columns

real_df = new_df[['RECNO ','Ter ','SSL', 'customer/consignee', 'Container No']]

real_df.head(100)
# Out:
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_13756\1638813477.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
#        RECNO  Ter   SSL                customer/consignee Container No
# 838   1937309  DAL  CMA  SAMSDTX/BEST BUY 075 C/O SAMSUNG   SEKU593730
# 838   1937309  DAL  CMA  SAMSDTX/BEST BUY 075 C/O SAMSUNG   SEKU593730
# 973   1937790  DAL  OOC                       JEFFFTX/IDC   RFCU407093
# 1011  1937591  DAL  OOC                       JEFFFTX/IDC   TRHU473792
# 579   1936726  DAL  CMA  SAMSDTX/BEST BUY 075 C/O SAMSUNG   CRSU928731
# 1022  1937648  DAL  OOC                         VICIL/IDC   CSNU701478
# 1026  1937652  DAL  OOC                         VICIL/IDC   TGBU470492
# 577   1936724  DAL  CMA  SAMSDTX/BEST BUY 075 C/O SAMSUNG   CMAU787522
# 581   1936728  DAL  CMA  SAMSDTX/BEST BUY 075 C/O SAMSUNG   TCNU769430
# 848   1937389  DAL  CMA  SAMSDTX/BEST BUY 075 C/O SAMSUNG   CAIU974332
# 851   1937392  DAL  CMA  SAMSDTX/BEST BUY 075 C/O SAMSUNG   CMAU768256
# 1025  1937651  DAL  OOC                         VICIL/IDC   OOLU941091
# 578   1936725  DAL  CMA  SAMSDTX/BEST BUY 075 C/O SAMSUNG   CMAU891934
# 1023  1937649  DAL  OOC                         VICIL/IDC   OOCU762053
# 974   1937791  DAL  OOC                       JEFFFTX/IDC   FSCU870979
# 1042  1937952  DAL  CMA          JEFFFTX/MORRISON EXPRESS   RONU200202
# 837   1937308  DAL  CMA  SAMSDTX/BEST BUY 075 C/O SAMSUNG   MAGU570162
# 575   1936722  DAL  CMA  SAMSDTX/BEST BUY 075 C/O SAMSUNG   APHU734270
# 1010  1937590  DAL  OOC                       JEFFFTX/IDC   OOLU963321
# 394   1935878  DAL  OOC     MEMETN/FRESENIUS MEDICAL CARE   CSNU718481
# 975   1937792  DAL  OOC           JEFFFTX/HESSELBEIN TIRE   CSNU692633
# 841   1937312  DAL  CMA  SAMSDTX/BEST BUY 075 C/O SAMSUNG   TRHU520018
# 842   1937313  DAL  CMA  SAMSDTX/BEST BUY 075 C/O SAMSUNG   TRLU737149

# %%
with pd.ExcelWriter('output.xlsx') as writer:
    real_df.to_excel(writer, sheet_name='Sheet 1')
