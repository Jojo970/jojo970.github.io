# %%
import numpy as np
import pandas as pd

# %%
df_main = pd.read_csv('file.csv')



df_find = pd.read_csv('recno.csv')

# %%
df_main.dtypes
# Out:
# RECNO                     float64
# TName                      object
# Company                    object
# Div_LES                    object
# Terminal                   object
# Status                     object
# ChassisNo                  object
# CONTAINERNO                object
# LI_NO                     float64
# QTY_LE                    float64
# SVCCODE_LE                 object
# SVCDESCRIPTION_LE          object
# RATECODE_LE                object
# RATE_LE                   float64
# CHGAMT_LE                 float64
# chz_pickup_loc             object
# Shipper_Name               object
# ConsigneeID                object
# Consignee_Name             object
# BilltoID_LES               object
# Billto_Name_LES            object
# Preferred                  object
# WorkorderNo                object
# PBI_RefNo                  object
# BOL                        object
# SSL                        object
# PU_Date                    object
# PU_Time                   float64
# Original_SchedDelv         object
# SchedDelv                  object
# Original_scheddelvtime    float64
# Scheddelvtime             float64
# POD_Date                   object
# POD_Time                   object
# Ingatedate                 object
# ReturnTo                   object
# CHZ_returnTo               object
# CHZ_ingatedate             object
# RECEIVEDBY                 object
# YARDID                     object
# LASTFREEDAY                object
# FREEDAYS                  float64
# LAST_RETURN                object
# Linehaul_Amount           float64
# FSC_Amount                float64
# Line_Total                float64
# ChasFee_Total             float64
# EL_Bill_Total             float64
# DP_Total                  float64
# MP_Total                  float64
# Net_Total                 float64
# Rel_Date                   object
# Billed_Date_LES            object
# Rcvd_Date_LES              object
# CUST_REF                   object
# dtype: object

# %%
n = 0

for x, y in df_find['recno'].iteritems():
    new_df = df_main[df_main['RECNO'].isin([y])]
    break
    
for x, y in df_find['recno'].iteritems():
    check = df_main['RECNO'].isin([y])
    if check.any() == True:
        to_append = df_main[df_main['RECNO'].isin([y])]
        new_df = new_df.append(to_append)
        
        
    else:
        n+=1
        new_df = new_df.append(pd.Series(), ignore_index = True)
        new_df.fillna(value = n, inplace =True)


new_df.columns

real_df = new_df[['RECNO', 'CHGAMT_LE']]

real_df.head(10)
# Out:
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:16: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_df = new_df.append(pd.Series(), ignore_index = True)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(pd.Series(), ignore_index = True)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
# C:\Users\ccs3\AppData\Local\Temp\ipykernel_14168\2048605596.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(to_append)
#           RECNO  CHGAMT_LE
# 0     1932586.0      480.0
# 1     1932586.0      480.0
# 2     1932587.0      480.0
# 3     1933254.0       80.0
# 4     1933255.0      200.0
# 5     1933259.0      160.0
# 6           1.0        1.0
# 1432  1930798.0      240.0
# 1731  1931344.0     2560.0
# 3271  1933934.0       40.0

# %%
with pd.ExcelWriter('yst_out.xlsx') as writer:
    real_df.to_excel(writer, sheet_name='Sheet 1')
